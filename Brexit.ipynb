# %% [markdown]
# ## Setup

# %% [markdown]
# ### Utils

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.30.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)

# %%
from scipy.spatial.distance import cosine

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from transformers import AutoTokenizer, BertModel
model = BertModel.from_pretrained('bert-base-multilingual-cased', output_hidden_states = True)
tokenizer = AutoTokenizer.from_pretrained("bert-base-multilingual-cased")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]

# %%
from transformers import AutoTokenizer, BertModel
model = BertModel.from_pretrained('bert-base-uncased', output_hidden_states = True)
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
from Utils import BERT_Embeddings, preprocessing, tokens_evaluation
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import pandas as pd
import numpy as np
import torch
from IPython.display import HTML
from tqdm import tqdm

# %%
from sklearn.metrics import classification_report

# %% [markdown]
# ### Load training Data

# %%
train_df = pd.read_json("./HS-Brexit_dataset/HS-Brexit_train.json", orient='index')
train_df = preprocessing.get_dataset_labels(train_df)
train_df
# Out:
#                                          original_text  hard_label  \
# 1    <user> <user> I'm so glad about #Brexit.. My a...           0
# 2    RT <user>: There was more to #Brexit than immi...           0
# 3    At the end of the day, the leave campaign won ...           0
# 4    So the reducing migration thing wasn't quite w...           0
# 5    A Brit Immigrant Asks Britain to Become India’...           0
# ..                                                 ...         ...
# 780  #Brexit has to happen there is no way you can ...           0
# 781  A foreigner we've neither heard of nor voted f...           0
# 782  The irony is we will probably now look to appo...           0
# 783  Better watch out Merkel, the German people don...           0
# 784  #Brexit is served.  In 2015, $66.4B of intl ca...           0
#
#      soft_label_0  soft_label_1  disagreement
# 1             1.0           0.0             1
# 2             1.0           0.0             1
# 3             1.0           0.0             1
# 4             1.0           0.0             1
# 5             1.0           0.0             1
# ..            ...           ...           ...
# 780           1.0           0.0             1
# 781           1.0           0.0             1
# 782           1.0           0.0             1
# 783           0.5           0.5             0
# 784           1.0           0.0             1
#
# [784 rows x 5 columns]

# %%
# sentences
train_df['sentences'] = train_df['original_text'].apply(lambda x : preprocessing.split_sentence(x))
train_df['sentences'] = train_df['sentences'].apply(lambda x :preprocessing.adjust_split(x))
train_df['sentences'] = train_df['sentences'].apply(lambda x : preprocessing.apply_lemmatization(x))

# %%
train_df['tokens_lists'] = train_df['sentences'].apply(lambda x: preprocessing.sentences_tokenizer(x))
train_df['tokens_lists']= train_df['tokens_lists'].apply(lambda x: preprocessing.clear_tokens(x))
train_df['tokens_list']= train_df['tokens_lists'].apply(lambda x: preprocessing.flatten_list(x))

# %%
train_df
# Out:
#                                          original_text  hard_label  \
# 1    <user> <user> I'm so glad about #Brexit.. My a...           0
# 2    RT <user>: There was more to #Brexit than immi...           0
# 3    At the end of the day, the leave campaign won ...           0
# 4    So the reducing migration thing wasn't quite w...           0
# 5    A Brit Immigrant Asks Britain to Become India’...           0
# ..                                                 ...         ...
# 780  #Brexit has to happen there is no way you can ...           0
# 781  A foreigner we've neither heard of nor voted f...           0
# 782  The irony is we will probably now look to appo...           0
# 783  Better watch out Merkel, the German people don...           0
# 784  #Brexit is served.  In 2015, $66.4B of intl ca...           0
#
#      soft_label_0  soft_label_1  disagreement  \
# 1             1.0           0.0             1
# 2             1.0           0.0             1
# 3             1.0           0.0             1
# 4             1.0           0.0             1
# 5             1.0           0.0             1
# ..            ...           ...           ...
# 780           1.0           0.0             1
# 781           1.0           0.0             1
# 782           1.0           0.0             1
# 783           0.5           0.5             0
# 784           1.0           0.0             1
#
#                                              sentences  \
# 1    [<user> <user> I be so glad about #Brexit, my ...
# 2    [RT <user>, there be more to #Brexit than immi...
# 3    [at the end of the day, the leave campaign win...
# 4    [so the reduce migration thing be not quite wh...
# 5    [a Brit immigrant ask Britain to become India ...
# ..                                                 ...
# 780  [#Brexit have to happen there be no way you ca...
# 781  [a foreigner we 've neither hear of nor vote f...
# 782  [the irony be we will probably now look to app...
# 783  [well watch out merkel, the german people do n...
# 784  [#Brexit be serve, in 2015, 4b of intl capital...
#
#                                           tokens_lists  \
# 1    [[glad, #brexit], [ancestor, england], [uk], [...
# 2                     [[#brexit, immigration, ugghhh]]
# 3    [[end, day], [leave, campaign, win, #brexit, d...
# 4    [[reduce, migration, thing, quite, seem, either]]
# 5    [[brit, immigrant, ask, britain, become, india...
# ..                                                 ...
# 780  [[#brexit, happen, way, set, minimum, wage, ke...
# 781  [[foreigner, neither, hear, vote, care, warn, ...
# 782  [[irony, probably, look, appoint, foreign, man...
# 783  [[well, watch, merkel], [german, people, like,...
# 784  [[#brexit, serve], [4b, intl, capital, flow, u...
#
#                                            tokens_list
# 1    [glad, #brexit, ancestor, england, uk, break, ...
# 2                       [#brexit, immigration, ugghhh]
# 3    [end, day, leave, campaign, win, #brexit, due,...
# 4      [reduce, migration, thing, quite, seem, either]
# 5    [brit, immigrant, ask, britain, become, india,...
# ..                                                 ...
# 780  [#brexit, happen, way, set, minimum, wage, kee...
# 781  [foreigner, neither, hear, vote, care, warn, #...
# 782  [irony, probably, look, appoint, foreign, mana...
# 783  [well, watch, merkel, german, people, like, mu...
# 784  [#brexit, serve, 4b, intl, capital, flow, uk, ...
#
# [784 rows x 8 columns]

# %%
train_df['original_text']= train_df['tokens_list'].apply(lambda x: ' '.join(x))
train_df
# Out:
#                                          original_text  hard_label  \
# 1    glad #brexit ancestor england uk break heart s...           0
# 2                           #brexit immigration ugghhh           0
# 3    end day leave campaign win #brexit due anti im...           0
# 4             reduce migration thing quite seem either           0
# 5    brit immigrant ask britain become india union ...           0
# ..                                                 ...         ...
# 780  #brexit happen way set minimum wage keep migra...           0
# 781      foreigner neither hear vote care warn #brexit           0
# 782  irony probably look appoint foreign manager #e...           0
# 783  well watch merkel german people like muslim in...           0
# 784  #brexit serve 4b intl capital flow uk cre tota...           0
#
#      soft_label_0  soft_label_1  disagreement  \
# 1             1.0           0.0             1
# 2             1.0           0.0             1
# 3             1.0           0.0             1
# 4             1.0           0.0             1
# 5             1.0           0.0             1
# ..            ...           ...           ...
# 780           1.0           0.0             1
# 781           1.0           0.0             1
# 782           1.0           0.0             1
# 783           0.5           0.5             0
# 784           1.0           0.0             1
#
#                                              sentences  \
# 1    [<user> <user> I be so glad about #Brexit, my ...
# 2    [RT <user>, there be more to #Brexit than immi...
# 3    [at the end of the day, the leave campaign win...
# 4    [so the reduce migration thing be not quite wh...
# 5    [a Brit immigrant ask Britain to become India ...
# ..                                                 ...
# 780  [#Brexit have to happen there be no way you ca...
# 781  [a foreigner we 've neither hear of nor vote f...
# 782  [the irony be we will probably now look to app...
# 783  [well watch out merkel, the german people do n...
# 784  [#Brexit be serve, in 2015, 4b of intl capital...
#
#                                           tokens_lists  \
# 1    [[glad, #brexit], [ancestor, england], [uk], [...
# 2                     [[#brexit, immigration, ugghhh]]
# 3    [[end, day], [leave, campaign, win, #brexit, d...
# 4    [[reduce, migration, thing, quite, seem, either]]
# 5    [[brit, immigrant, ask, britain, become, india...
# ..                                                 ...
# 780  [[#brexit, happen, way, set, minimum, wage, ke...
# 781  [[foreigner, neither, hear, vote, care, warn, ...
# 782  [[irony, probably, look, appoint, foreign, man...
# 783  [[well, watch, merkel], [german, people, like,...
# 784  [[#brexit, serve], [4b, intl, capital, flow, u...
#
#                                            tokens_list
# 1    [glad, #brexit, ancestor, england, uk, break, ...
# 2                       [#brexit, immigration, ugghhh]
# 3    [end, day, leave, campaign, win, #brexit, due,...
# 4      [reduce, migration, thing, quite, seem, either]
# 5    [brit, immigrant, ask, britain, become, india,...
# ..                                                 ...
# 780  [#brexit, happen, way, set, minimum, wage, kee...
# 781  [foreigner, neither, hear, vote, care, warn, #...
# 782  [irony, probably, look, appoint, foreign, mana...
# 783  [well, watch, merkel, german, people, like, mu...
# 784  [#brexit, serve, 4b, intl, capital, flow, uk, ...
#
# [784 rows x 8 columns]

# %% [markdown]
# ### Load Dev Data

# %%
dev_df = pd.read_json("./HS-Brexit_dataset/HS-Brexit_dev.json", orient='index')
dev_df = preprocessing.get_dataset_labels(dev_df)

# %%
# sentences
dev_df['sentences'] = dev_df['original_text'].apply(lambda x : preprocessing.split_sentence(x))
dev_df['sentences'] = dev_df['sentences'].apply(lambda x :preprocessing.adjust_split(x))
dev_df['sentences'] = dev_df['sentences'].apply(lambda x : preprocessing.apply_lemmatization(x))
dev_df['tokens_lists'] = dev_df['sentences'].apply(lambda x: preprocessing.sentences_tokenizer(x))
dev_df['tokens_lists']= dev_df['tokens_lists'].apply(lambda x: preprocessing.clear_tokens(x))
dev_df['tokens_list']= dev_df['tokens_lists'].apply(lambda x: preprocessing.flatten_list(x))

# %%
dev_df['original_text']= dev_df['tokens_list'].apply(lambda x: ' '.join(x))
dev_df
# Out:
#                                          original_text  hard_label  \
# 1    cheap mean foreigner flock summer oh irony #br...           0
# 2    #brexitornot easy #brexit protect country unco...           0
# 3    #brexit sum one word terrorism radical islam t...           0
# 4    putin say #brexit reflect unhappiness migratio...           0
# 5    #brexit look likely anti immigration much stro...           0
# ..                                                 ...         ...
# 164  sky news interview guy muslims britain pro #br...           0
# 165  #brexit anyway deport mark lawrenson fucking hate           0
# 166  europe collapse worry welcome refugee #byzanti...           0
# 167  #brexit cheap foreign tourist come #uk ☔ expen...           0
# 168  #brexit reclaiming england independence irony ...           0
#
#      soft_label_0  soft_label_1  disagreement  \
# 1            1.00          0.00             1
# 2            0.67          0.33             0
# 3            0.50          0.50             0
# 4            1.00          0.00             1
# 5            1.00          0.00             1
# ..            ...           ...           ...
# 164          1.00          0.00             1
# 165          0.50          0.50             0
# 166          0.67          0.33             0
# 167          1.00          0.00             1
# 168          1.00          0.00             1
#
#                                              sentences  \
# 1    [cheap £ mean foreigner will be flock here thi...
# 2    [#BrexitOrNot, easy, #BREXIT and protect your ...
# 3    [<user> #brexit to sum it up in just one word,...
# 4    [Putin say #Brexit reflect unhappiness with mi...
# 5    [#Brexit be look likely, but anti, immigration...
# ..                                                 ...
# 164  [sky news be interview a guy from, Muslims for...
# 165  [after this #brexit, be there anyway we can de...
# 166  [<user> Europe be collapse, do not worry we we...
# 167  [#Brexit its now cheap for foreign tourist to ...
# 168  [so #Brexit be a reclaiming of England 's inde...
#
#                                           tokens_lists  \
# 1    [[cheap, mean, foreigner, flock, summer], [oh,...
# 2    [[#brexitornot], [easy], [#brexit, protect, co...
# 3    [[#brexit, sum, one, word], [terrorism], [radi...
# 4    [[putin, say, #brexit, reflect, unhappiness, m...
# 5    [[#brexit, look, likely], [anti], [immigration...
# ..                                                 ...
# 164  [[sky, news, interview, guy], [muslims, britai...
# 165  [[#brexit], [anyway, deport, mark, lawrenson],...
# 166  [[europe, collapse], [worry, welcome, refugee,...
# 167  [[#brexit, cheap, foreign, tourist, come, #uk,...
# 168  [[#brexit, reclaiming, england, independence],...
#
#                                            tokens_list
# 1    [cheap, mean, foreigner, flock, summer, oh, ir...
# 2    [#brexitornot, easy, #brexit, protect, country...
# 3    [#brexit, sum, one, word, terrorism, radical, ...
# 4    [putin, say, #brexit, reflect, unhappiness, mi...
# 5    [#brexit, look, likely, anti, immigration, muc...
# ..                                                 ...
# 164  [sky, news, interview, guy, muslims, britain, ...
# 165  [#brexit, anyway, deport, mark, lawrenson, fuc...
# 166  [europe, collapse, worry, welcome, refugee, #b...
# 167  [#brexit, cheap, foreign, tourist, come, #uk, ...
# 168  [#brexit, reclaiming, england, independence, i...
#
# [168 rows x 8 columns]

# %% [markdown]
# ### Load Test Data

# %%
test_df = pd.read_json("./HS-Brexit_dataset/HS-Brexit_test.json", orient='index')
test_df = preprocessing.get_dataset_labels(test_df)

# %%
# sentences
test_df['sentences'] = test_df['original_text'].apply(lambda x : preprocessing.split_sentence(x))
test_df['sentences'] = test_df['sentences'].apply(lambda x :preprocessing.adjust_split(x))
test_df['sentences'] = test_df['sentences'].apply(lambda x : preprocessing.apply_lemmatization(x))
test_df['tokens_lists'] = test_df['sentences'].apply(lambda x: preprocessing.sentences_tokenizer(x))
test_df['tokens_lists']= test_df['tokens_lists'].apply(lambda x: preprocessing.clear_tokens(x))
test_df['tokens_list']= test_df['tokens_lists'].apply(lambda x: preprocessing.flatten_list(x))

# %%
test_df['original_text']= test_df['tokens_list'].apply(lambda x: ' '.join(x))
test_df
# Out:
#                                          original_text  hard_label  \
# 1    uk decide leave european union mean foreign pr...           0
# 2    good brit save country seal muslim invasian #b...           1
# 3    vote nowt immigration identity control interes...           0
# 4    support #brexit support scapegoating muslim immig           0
# 5    say year early really mean deport oh wait vote...           0
# ..                                                 ...         ...
# 164  hmm #brexit really change immigration policy w...           0
# 165  sadiq isis muslim mayor total lunatic explode ...           1
# 166  fusilier lee rigby lt forget #brexit vote cont...           1
# 167  world know #trump one worthy run usa unless mu...           0
# 168  prop putin guess russia weaponize migration de...           0
#
#      soft_label_0  soft_label_1  disagreement  \
# 1            1.00          0.00             1
# 2            0.33          0.67             0
# 3            1.00          0.00             1
# 4            1.00          0.00             1
# 5            0.67          0.33             0
# ..            ...           ...           ...
# 164          1.00          0.00             1
# 165          0.50          0.50             0
# 166          0.50          0.50             0
# 167          1.00          0.00             1
# 168          1.00          0.00             1
#
#                                              sentences  \
# 1    [the UK have decide to leave the European Unio...
# 2    [good for you brit, you save your country, now...
# 3    [I be vote out, nowt to do with immigration or...
# 4    [RT <user>, <user> <user> <user> <user> I supp...
# 5    [<user> u say 8 year early, 18 really mean 9, ...
# ..                                                 ...
# 164  [<user> Hmm, for #Brexit they can not really c...
# 165  [Sadiq, isis muslim mayor be a total lunatic a...
# 166  [Fusilier Lee Rigby, lt, not forget during the...
# 167  [because the world know #Trump be the only one...
# 168  [prop to Putin, I guess, how Russia be ' weapo...
#
#                                           tokens_lists  \
# 1    [[uk, decide, leave, european, union], [mean, ...
# 2    [[good, brit], [save, country], [seal, muslim,...
# 3    [[vote], [nowt, immigration, identity, control...
# 4    [[support, #brexit], [support, scapegoating, m...
# 5    [[say, year, early], [really, mean], [deport],...
# ..                                                 ...
# 164  [[hmm], [#brexit, really, change, immigration,...
# 165  [[sadiq], [isis, muslim, mayor, total, lunatic...
# 166  [[fusilier, lee, rigby], [lt], [forget, #brexi...
# 167  [[world, know, #trump, one, worthy, run, usa],...
# 168  [[prop, putin], [guess], [russia, weaponize, m...
#
#                                            tokens_list
# 1    [uk, decide, leave, european, union, mean, for...
# 2    [good, brit, save, country, seal, muslim, inva...
# 3    [vote, nowt, immigration, identity, control, i...
# 4    [support, #brexit, support, scapegoating, musl...
# 5    [say, year, early, really, mean, deport, oh, w...
# ..                                                 ...
# 164  [hmm, #brexit, really, change, immigration, po...
# 165  [sadiq, isis, muslim, mayor, total, lunatic, e...
# 166  [fusilier, lee, rigby, lt, forget, #brexit, vo...
# 167  [world, know, #trump, one, worthy, run, usa, u...
# 168  [prop, putin, guess, russia, weaponize, migrat...
#
# [168 rows x 8 columns]

# %% [markdown]
# ## Baseline

# %%
tokens_df = pd.read_csv('../Nuovi_Scores/brexit_scores.csv', sep='\t')
tokens_df_10 = tokens_df[tokens_df.occurrences >= 10]

# %% [markdown]
# ### Threshold estimation from Dev

# %%
pred_somma = []
pred_tutti_verdi = []
pred_media = []
pred_mediana = []

for _, row in tqdm(dev_df.iterrows()):
  colors_agreement, _ = tokens_evaluation.get_all_colors(row['tokens_list'], tokens_df_10)

  if 'NA' in colors_agreement:
    indexes = tokens_evaluation.find_NA_indices(colors_agreement)
    for new_word_index in range(len(indexes)) :
      colors_agreement[indexes[new_word_index]]=0

  colors_agreement = [i for i in colors_agreement if i != 0]

  if colors_agreement:

    pred_somma.append(sum(colors_agreement))
    pred_media.append(np.mean(colors_agreement))
    pred_mediana.append(np.median(colors_agreement))
    pred_tutti_verdi.append(min(colors_agreement))

  else:
    pred_somma.append(0)
    pred_media.append(0)
    pred_mediana.append(0)
    pred_tutti_verdi.append(0)

# %%
print('stima NA: NO')
print('threshold variabile (da -0.9 a +0.9)')

t= -1
for threshold in range(19):
  t = t + 0.1
  t = round(t,1)
  print('THRESHOLD: '+ str(t) + '\n')

  print('SOMMA \n')
  print(classification_report(dev_df['disagreement'], [int(i>=t) for i in pred_somma] ))
# Out:
# stima NA: NO
# soglia coordinate: almeno 10 occorrenze
# valori non pesati
# threshold variabile (da -0.9 a +0.9)
# THRESHOLD: -0.9
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.8
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.7
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.6
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.5
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.4
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      0.99      0.81       116
#
#     accuracy                           0.68       168
#    macro avg       0.34      0.50      0.41       168
# weighted avg       0.48      0.68      0.56       168
#
# THRESHOLD: -0.3
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.04      0.07        52
#            1       0.70      0.99      0.82       116
#
#     accuracy                           0.70       168
#    macro avg       0.68      0.51      0.45       168
# weighted avg       0.69      0.70      0.59       168
#
# THRESHOLD: -0.2
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.06      0.11        52
#            1       0.70      0.99      0.82       116
#
#     accuracy                           0.70       168
#    macro avg       0.73      0.52      0.46       168
# weighted avg       0.72      0.70      0.60       168
#
# THRESHOLD: -0.1
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.06      0.11        52
#            1       0.70      0.98      0.82       116
#
#     accuracy                           0.70       168
#    macro avg       0.65      0.52      0.46       168
# weighted avg       0.67      0.70      0.60       168
#
# THRESHOLD: 0.0
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.08      0.14        52
#            1       0.70      0.98      0.82       116
#
#     accuracy                           0.70       168
#    macro avg       0.69      0.53      0.48       168
# weighted avg       0.69      0.70      0.61       168
#
# THRESHOLD: 0.1
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.21      0.34        52
#            1       0.74      0.98      0.84       116
#
#     accuracy                           0.74       168
#    macro avg       0.79      0.60      0.59       168
# weighted avg       0.77      0.74      0.69       168
#
# THRESHOLD: 0.2
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.21      0.34        52
#            1       0.74      0.98      0.84       116
#
#     accuracy                           0.74       168
#    macro avg       0.79      0.60      0.59       168
# weighted avg       0.77      0.74      0.69       168
#
# THRESHOLD: 0.3
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.25      0.38        52
#            1       0.74      0.97      0.84       116
#
#     accuracy                           0.75       168
#    macro avg       0.78      0.61      0.61       168
# weighted avg       0.76      0.75      0.70       168
#
# THRESHOLD: 0.4
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.25      0.38        52
#            1       0.74      0.97      0.84       116
#
#     accuracy                           0.74       168
#    macro avg       0.75      0.61      0.61       168
# weighted avg       0.75      0.74      0.70       168
#
# THRESHOLD: 0.5
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.29      0.41        52
#            1       0.75      0.95      0.84       116
#
#     accuracy                           0.74       168
#    macro avg       0.73      0.62      0.62       168
# weighted avg       0.74      0.74      0.70       168
#
# THRESHOLD: 0.6
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.29      0.40        52
#            1       0.74      0.93      0.83       116
#
#     accuracy                           0.73       168
#    macro avg       0.70      0.61      0.61       168
# weighted avg       0.72      0.73      0.70       168
#
# THRESHOLD: 0.7
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.33      0.42        52
#            1       0.75      0.91      0.82       116
#
#     accuracy                           0.73       168
#    macro avg       0.68      0.62      0.62       168
# weighted avg       0.71      0.73      0.70       168
#
# THRESHOLD: 0.8
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.35      0.43        52
#            1       0.75      0.89      0.81       116
#
#     accuracy                           0.72       168
#    macro avg       0.67      0.62      0.62       168
# weighted avg       0.70      0.72      0.70       168
#
# THRESHOLD: 0.9
#
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.37      0.45        52
#            1       0.76      0.88      0.81       116
#
#     accuracy                           0.72       168
#    macro avg       0.67      0.62      0.63       168
# weighted avg       0.70      0.72      0.70       168

# %%
print('stima NA: NO')
print('threshold variabile (da -0.9 a +0.9)')

t= -1
for threshold in range(38):
  t = t + 0.05
  t = round(t,2)
  print('THRESHOLD: '+ str(t) + '\n')

  print('\n MEDIA \n')
  print(classification_report(dev_df['disagreement'], [int(i>=t) for i in pred_media]))
# Out:
# stima NA: NO
# soglia coordinate: almeno 10 occorrenze
# valori non pesati
# threshold variabile (da -0.9 a +0.9)
# THRESHOLD: -0.95
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.9
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.85
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.8
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.75
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.7
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.65
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.6
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.55
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.5
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.45
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.4
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.35
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.3
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.25
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.2
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.15
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.1
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.02      0.04        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.70       168
#    macro avg       0.85      0.51      0.43       168
# weighted avg       0.79      0.70      0.58       168
#
# THRESHOLD: -0.05
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.06      0.11        52
#            1       0.70      1.00      0.83       116
#
#     accuracy                           0.71       168
#    macro avg       0.85      0.53      0.47       168
# weighted avg       0.79      0.71      0.60       168
#
# THRESHOLD: 0.0
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.08      0.14        52
#            1       0.70      0.98      0.82       116
#
#     accuracy                           0.70       168
#    macro avg       0.69      0.53      0.48       168
# weighted avg       0.69      0.70      0.61       168
#
# THRESHOLD: 0.05
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.21      0.34        52
#            1       0.74      0.98      0.84       116
#
#     accuracy                           0.74       168
#    macro avg       0.79      0.60      0.59       168
# weighted avg       0.77      0.74      0.69       168
#
# THRESHOLD: 0.1
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.23      0.36        52
#            1       0.74      0.98      0.84       116
#
#     accuracy                           0.75       168
#    macro avg       0.80      0.61      0.60       168
# weighted avg       0.78      0.75      0.70       168
#
# THRESHOLD: 0.15
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.23      0.35        52
#            1       0.74      0.97      0.84       116
#
#     accuracy                           0.74       168
#    macro avg       0.74      0.60      0.59       168
# weighted avg       0.74      0.74      0.69       168
#
# THRESHOLD: 0.2
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.29      0.41        52
#            1       0.75      0.94      0.83       116
#
#     accuracy                           0.74       168
#    macro avg       0.71      0.61      0.62       168
# weighted avg       0.73      0.74      0.70       168
#
# THRESHOLD: 0.25
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.52      0.57        52
#            1       0.80      0.87      0.83       116
#
#     accuracy                           0.76       168
#    macro avg       0.72      0.69      0.70       168
# weighted avg       0.75      0.76      0.75       168
#
# THRESHOLD: 0.3
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.58      0.59        52
#            1       0.82      0.84      0.83       116
#
#     accuracy                           0.76       168
#    macro avg       0.71      0.71      0.71       168
# weighted avg       0.75      0.76      0.75       168
#
# THRESHOLD: 0.35
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.67      0.64        52
#            1       0.85      0.81      0.83       116
#
#     accuracy                           0.77       168
#    macro avg       0.73      0.74      0.74       168
# weighted avg       0.77      0.77      0.77       168
#
# THRESHOLD: 0.4
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.77      0.66        52
#            1       0.88      0.74      0.80       116
#
#     accuracy                           0.75       168
#    macro avg       0.72      0.76      0.73       168
# weighted avg       0.78      0.75      0.76       168
#
# THRESHOLD: 0.45
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.51      0.81      0.62        52
#            1       0.88      0.65      0.75       116
#
#     accuracy                           0.70       168
#    macro avg       0.69      0.73      0.68       168
# weighted avg       0.77      0.70      0.71       168
#
# THRESHOLD: 0.5
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.42      0.87      0.57        52
#            1       0.89      0.47      0.62       116
#
#     accuracy                           0.60       168
#    macro avg       0.66      0.67      0.59       168
# weighted avg       0.74      0.60      0.60       168
#
# THRESHOLD: 0.55
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.96      0.54        52
#            1       0.94      0.29      0.45       116
#
#     accuracy                           0.50       168
#    macro avg       0.66      0.63      0.50       168
# weighted avg       0.77      0.50      0.48       168
#
# THRESHOLD: 0.6
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.35      0.98      0.52        52
#            1       0.96      0.19      0.32       116
#
#     accuracy                           0.43       168
#    macro avg       0.65      0.59      0.42       168
# weighted avg       0.77      0.43      0.38       168
#
# THRESHOLD: 0.65
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50        52
#            1       1.00      0.09      0.16       116
#
#     accuracy                           0.37       168
#    macro avg       0.66      0.54      0.33       168
# weighted avg       0.79      0.37      0.26       168
#
# THRESHOLD: 0.7
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.48        52
#            1       1.00      0.02      0.03       116
#
#     accuracy                           0.32       168
#    macro avg       0.66      0.51      0.26       168
# weighted avg       0.79      0.32      0.17       168
#
# THRESHOLD: 0.75
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        52
#            1       0.00      0.00      0.00       116
#
#     accuracy                           0.31       168
#    macro avg       0.15      0.50      0.24       168
# weighted avg       0.10      0.31      0.15       168
#
# THRESHOLD: 0.8
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        52
#            1       0.00      0.00      0.00       116
#
#     accuracy                           0.31       168
#    macro avg       0.15      0.50      0.24       168
# weighted avg       0.10      0.31      0.15       168
#
# THRESHOLD: 0.85
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        52
#            1       0.00      0.00      0.00       116
#
#     accuracy                           0.31       168
#    macro avg       0.15      0.50      0.24       168
# weighted avg       0.10      0.31      0.15       168
#
# THRESHOLD: 0.9
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        52
#            1       0.00      0.00      0.00       116
#
#     accuracy                           0.31       168
#    macro avg       0.15      0.50      0.24       168
# weighted avg       0.10      0.31      0.15       168

# %%
print('stima NA: NO')
print('threshold variabile (da -0.9 a +0.9)')

t= -1
for threshold in range(38):
  t = t + 0.05
  t = round(t,2)
  print('THRESHOLD: '+ str(t) + '\n')

  print('\n MEDIANA \n')
  print(classification_report(dev_df['disagreement'], [int(i>=t) for i in pred_mediana]))
# Out:
# stima NA: NO
# soglia coordinate: almeno 10 occorrenze
# valori non pesati
# threshold variabile (da -0.9 a +0.9)
# THRESHOLD: -0.95
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.9
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.85
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.8
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.75
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.7
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.65
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.6
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.55
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.5
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.45
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.4
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.35
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.3
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.02      0.04        52
#            1       0.69      0.99      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.60      0.51      0.43       168
# weighted avg       0.63      0.69      0.57       168
#
# THRESHOLD: -0.25
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.02      0.04        52
#            1       0.69      0.99      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.60      0.51      0.43       168
# weighted avg       0.63      0.69      0.57       168
#
# THRESHOLD: -0.2
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.02      0.04        52
#            1       0.69      0.99      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.60      0.51      0.43       168
# weighted avg       0.63      0.69      0.57       168
#
# THRESHOLD: -0.15
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.02      0.04        52
#            1       0.69      0.99      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.60      0.51      0.43       168
# weighted avg       0.63      0.69      0.57       168
#
# THRESHOLD: -0.1
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.02      0.04        52
#            1       0.69      0.99      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.60      0.51      0.43       168
# weighted avg       0.63      0.69      0.57       168
#
# THRESHOLD: -0.05
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.06      0.11        52
#            1       0.70      0.98      0.82       116
#
#     accuracy                           0.70       168
#    macro avg       0.65      0.52      0.46       168
# weighted avg       0.67      0.70      0.60       168
#
# THRESHOLD: 0.0
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.10      0.17        52
#            1       0.71      0.98      0.82       116
#
#     accuracy                           0.71       168
#    macro avg       0.71      0.54      0.50       168
# weighted avg       0.71      0.71      0.62       168
#
# THRESHOLD: 0.05
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.21      0.34        52
#            1       0.74      0.98      0.84       116
#
#     accuracy                           0.74       168
#    macro avg       0.79      0.60      0.59       168
# weighted avg       0.77      0.74      0.69       168
#
# THRESHOLD: 0.1
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.21      0.34        52
#            1       0.74      0.98      0.84       116
#
#     accuracy                           0.74       168
#    macro avg       0.79      0.60      0.59       168
# weighted avg       0.77      0.74      0.69       168
#
# THRESHOLD: 0.15
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.21      0.34        52
#            1       0.74      0.98      0.84       116
#
#     accuracy                           0.74       168
#    macro avg       0.79      0.60      0.59       168
# weighted avg       0.77      0.74      0.69       168
#
# THRESHOLD: 0.2
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.23      0.36        52
#            1       0.74      0.97      0.84       116
#
#     accuracy                           0.74       168
#    macro avg       0.77      0.60      0.60       168
# weighted avg       0.76      0.74      0.69       168
#
# THRESHOLD: 0.25
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.29      0.42        52
#            1       0.75      0.97      0.85       116
#
#     accuracy                           0.76       168
#    macro avg       0.77      0.63      0.63       168
# weighted avg       0.76      0.76      0.71       168
#
# THRESHOLD: 0.3
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.33      0.46        52
#            1       0.76      0.96      0.85       116
#
#     accuracy                           0.76       168
#    macro avg       0.77      0.64      0.65       168
# weighted avg       0.76      0.76      0.73       168
#
# THRESHOLD: 0.35
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.38      0.51        52
#            1       0.77      0.94      0.85       116
#
#     accuracy                           0.77       168
#    macro avg       0.76      0.66      0.68       168
# weighted avg       0.76      0.77      0.74       168
#
# THRESHOLD: 0.4
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.50      0.53        52
#            1       0.79      0.83      0.81       116
#
#     accuracy                           0.73       168
#    macro avg       0.68      0.66      0.67       168
# weighted avg       0.72      0.73      0.72       168
#
# THRESHOLD: 0.45
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.41      0.79      0.54        52
#            1       0.84      0.49      0.62       116
#
#     accuracy                           0.58       168
#    macro avg       0.62      0.64      0.58       168
# weighted avg       0.71      0.58      0.59       168
#
# THRESHOLD: 0.5
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.39      0.88      0.54        52
#            1       0.88      0.38      0.53       116
#
#     accuracy                           0.54       168
#    macro avg       0.63      0.63      0.54       168
# weighted avg       0.73      0.54      0.53       168
#
# THRESHOLD: 0.55
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.35      0.94      0.51        52
#            1       0.88      0.20      0.32       116
#
#     accuracy                           0.43       168
#    macro avg       0.61      0.57      0.41       168
# weighted avg       0.72      0.43      0.38       168
#
# THRESHOLD: 0.6
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.94      0.49        52
#            1       0.85      0.15      0.25       116
#
#     accuracy                           0.39       168
#    macro avg       0.59      0.54      0.37       168
# weighted avg       0.69      0.39      0.32       168
#
# THRESHOLD: 0.65
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.34      1.00      0.50        52
#            1       1.00      0.11      0.20       116
#
#     accuracy                           0.39       168
#    macro avg       0.67      0.56      0.35       168
# weighted avg       0.79      0.39      0.29       168
#
# THRESHOLD: 0.7
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.32      1.00      0.49        52
#            1       1.00      0.05      0.10       116
#
#     accuracy                           0.35       168
#    macro avg       0.66      0.53      0.29       168
# weighted avg       0.79      0.35      0.22       168
#
# THRESHOLD: 0.75
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.32      1.00      0.48        52
#            1       1.00      0.03      0.07       116
#
#     accuracy                           0.33       168
#    macro avg       0.66      0.52      0.27       168
# weighted avg       0.79      0.33      0.20       168
#
# THRESHOLD: 0.8
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        52
#            1       1.00      0.01      0.02       116
#
#     accuracy                           0.32       168
#    macro avg       0.66      0.50      0.25       168
# weighted avg       0.79      0.32      0.16       168
#
# THRESHOLD: 0.85
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        52
#            1       1.00      0.01      0.02       116
#
#     accuracy                           0.32       168
#    macro avg       0.66      0.50      0.25       168
# weighted avg       0.79      0.32      0.16       168
#
# THRESHOLD: 0.9
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        52
#            1       0.00      0.00      0.00       116
#
#     accuracy                           0.31       168
#    macro avg       0.15      0.50      0.24       168
# weighted avg       0.10      0.31      0.15       168

# %%
print('stima NA: NO')
print('threshold variabile (da -0.9 a +0.9)')

t= -1
for threshold in range(38):
  t = t + 0.05
  t = round(t,2)
  print('THRESHOLD: '+ str(t) + '\n')

  print('\n ALL GREEN \n')
  print(classification_report(dev_df['disagreement'], [int(i>=t) for i in pred_tutti_verdi]))
# Out:
# stima NA: NO
# soglia coordinate: almeno 10 occorrenze
# valori non pesati
# threshold variabile (da -0.9 a +0.9)
# THRESHOLD: -0.95
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.9
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.85
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        52
#            1       0.69      1.00      0.82       116
#
#     accuracy                           0.69       168
#    macro avg       0.35      0.50      0.41       168
# weighted avg       0.48      0.69      0.56       168
#
# THRESHOLD: -0.8
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.08      0.14        52
#            1       0.71      1.00      0.83       116
#
#     accuracy                           0.71       168
#    macro avg       0.85      0.54      0.49       168
# weighted avg       0.80      0.71      0.62       168
#
# THRESHOLD: -0.75
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.08      0.14        52
#            1       0.71      0.99      0.82       116
#
#     accuracy                           0.71       168
#    macro avg       0.75      0.53      0.48       168
# weighted avg       0.73      0.71      0.61       168
#
# THRESHOLD: -0.7
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.08      0.14        52
#            1       0.71      0.99      0.82       116
#
#     accuracy                           0.71       168
#    macro avg       0.75      0.53      0.48       168
# weighted avg       0.73      0.71      0.61       168
#
# THRESHOLD: -0.65
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.08      0.14        52
#            1       0.71      0.99      0.82       116
#
#     accuracy                           0.71       168
#    macro avg       0.75      0.53      0.48       168
# weighted avg       0.73      0.71      0.61       168
#
# THRESHOLD: -0.6
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.10      0.17        52
#            1       0.71      0.98      0.82       116
#
#     accuracy                           0.71       168
#    macro avg       0.71      0.54      0.50       168
# weighted avg       0.71      0.71      0.62       168
#
# THRESHOLD: -0.55
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.10      0.17        52
#            1       0.71      0.98      0.82       116
#
#     accuracy                           0.71       168
#    macro avg       0.71      0.54      0.50       168
# weighted avg       0.71      0.71      0.62       168
#
# THRESHOLD: -0.5
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.10      0.17        52
#            1       0.71      0.98      0.82       116
#
#     accuracy                           0.71       168
#    macro avg       0.71      0.54      0.50       168
# weighted avg       0.71      0.71      0.62       168
#
# THRESHOLD: -0.45
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.27      0.39        52
#            1       0.74      0.95      0.83       116
#
#     accuracy                           0.74       168
#    macro avg       0.72      0.61      0.61       168
# weighted avg       0.73      0.74      0.70       168
#
# THRESHOLD: -0.4
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.40      0.53        52
#            1       0.78      0.95      0.86       116
#
#     accuracy                           0.78       168
#    macro avg       0.78      0.68      0.69       168
# weighted avg       0.78      0.78      0.76       168
#
# THRESHOLD: -0.35
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.42      0.54        52
#            1       0.78      0.93      0.85       116
#
#     accuracy                           0.77       168
#    macro avg       0.76      0.68      0.69       168
# weighted avg       0.77      0.77      0.75       168
#
# THRESHOLD: -0.3
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.69      0.67        52
#            1       0.86      0.84      0.85       116
#
#     accuracy                           0.79       168
#    macro avg       0.76      0.76      0.76       168
# weighted avg       0.80      0.79      0.79       168
#
# THRESHOLD: -0.25
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.69      0.67        52
#            1       0.86      0.84      0.85       116
#
#     accuracy                           0.79       168
#    macro avg       0.76      0.76      0.76       168
# weighted avg       0.80      0.79      0.79       168
#
# THRESHOLD: -0.2
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.69      0.67        52
#            1       0.86      0.83      0.84       116
#
#     accuracy                           0.79       168
#    macro avg       0.75      0.76      0.75       168
# weighted avg       0.79      0.79      0.79       168
#
# THRESHOLD: -0.15
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.71      0.65        52
#            1       0.86      0.79      0.83       116
#
#     accuracy                           0.77       168
#    macro avg       0.73      0.75      0.74       168
# weighted avg       0.78      0.77      0.77       168
#
# THRESHOLD: -0.1
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.71      0.64        52
#            1       0.86      0.78      0.81       116
#
#     accuracy                           0.76       168
#    macro avg       0.72      0.74      0.73       168
# weighted avg       0.77      0.76      0.76       168
#
# THRESHOLD: -0.05
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.73      0.63        52
#            1       0.86      0.74      0.80       116
#
#     accuracy                           0.74       168
#    macro avg       0.71      0.74      0.71       168
# weighted avg       0.77      0.74      0.75       168
#
# THRESHOLD: 0.0
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.73      0.63        52
#            1       0.86      0.74      0.80       116
#
#     accuracy                           0.74       168
#    macro avg       0.71      0.74      0.71       168
# weighted avg       0.77      0.74      0.75       168
#
# THRESHOLD: 0.05
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.75      0.64        52
#            1       0.87      0.74      0.80       116
#
#     accuracy                           0.74       168
#    macro avg       0.72      0.75      0.72       168
# weighted avg       0.77      0.74      0.75       168
#
# THRESHOLD: 0.1
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.75      0.64        52
#            1       0.87      0.74      0.80       116
#
#     accuracy                           0.74       168
#    macro avg       0.72      0.75      0.72       168
# weighted avg       0.77      0.74      0.75       168
#
# THRESHOLD: 0.15
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.46      0.77      0.58        52
#            1       0.85      0.59      0.70       116
#
#     accuracy                           0.65       168
#    macro avg       0.66      0.68      0.64       168
# weighted avg       0.73      0.65      0.66       168
#
# THRESHOLD: 0.2
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.46      0.79      0.58        52
#            1       0.86      0.58      0.69       116
#
#     accuracy                           0.64       168
#    macro avg       0.66      0.68      0.63       168
# weighted avg       0.73      0.64      0.66       168
#
# THRESHOLD: 0.25
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.42      0.85      0.56        52
#            1       0.87      0.47      0.61       116
#
#     accuracy                           0.59       168
#    macro avg       0.65      0.66      0.59       168
# weighted avg       0.73      0.59      0.60       168
#
# THRESHOLD: 0.3
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.85      0.54        52
#            1       0.86      0.43      0.57       116
#
#     accuracy                           0.56       168
#    macro avg       0.63      0.64      0.56       168
# weighted avg       0.72      0.56      0.56       168
#
# THRESHOLD: 0.35
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.85      0.54        52
#            1       0.86      0.43      0.57       116
#
#     accuracy                           0.56       168
#    macro avg       0.63      0.64      0.56       168
# weighted avg       0.72      0.56      0.56       168
#
# THRESHOLD: 0.4
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.36      0.88      0.51        52
#            1       0.85      0.29      0.44       116
#
#     accuracy                           0.48       168
#    macro avg       0.60      0.59      0.47       168
# weighted avg       0.70      0.48      0.46       168
#
# THRESHOLD: 0.45
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        52
#            1       1.00      0.01      0.02       116
#
#     accuracy                           0.32       168
#    macro avg       0.66      0.50      0.25       168
# weighted avg       0.79      0.32      0.16       168
#
# THRESHOLD: 0.5
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        52
#            1       1.00      0.01      0.02       116
#
#     accuracy                           0.32       168
#    macro avg       0.66      0.50      0.25       168
# weighted avg       0.79      0.32      0.16       168
#
# THRESHOLD: 0.55
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        52
#            1       0.00      0.00      0.00       116
#
#     accuracy                           0.31       168
#    macro avg       0.15      0.50      0.24       168
# weighted avg       0.10      0.31      0.15       168
#
# THRESHOLD: 0.6
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        52
#            1       0.00      0.00      0.00       116
#
#     accuracy                           0.31       168
#    macro avg       0.15      0.50      0.24       168
# weighted avg       0.10      0.31      0.15       168
#
# THRESHOLD: 0.65
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        52
#            1       0.00      0.00      0.00       116
#
#     accuracy                           0.31       168
#    macro avg       0.15      0.50      0.24       168
# weighted avg       0.10      0.31      0.15       168
#
# THRESHOLD: 0.7
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        52
#            1       0.00      0.00      0.00       116
#
#     accuracy                           0.31       168
#    macro avg       0.15      0.50      0.24       168
# weighted avg       0.10      0.31      0.15       168
#
# THRESHOLD: 0.75
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        52
#            1       0.00      0.00      0.00       116
#
#     accuracy                           0.31       168
#    macro avg       0.15      0.50      0.24       168
# weighted avg       0.10      0.31      0.15       168
#
# THRESHOLD: 0.8
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        52
#            1       0.00      0.00      0.00       116
#
#     accuracy                           0.31       168
#    macro avg       0.15      0.50      0.24       168
# weighted avg       0.10      0.31      0.15       168
#
# THRESHOLD: 0.85
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        52
#            1       0.00      0.00      0.00       116
#
#     accuracy                           0.31       168
#    macro avg       0.15      0.50      0.24       168
# weighted avg       0.10      0.31      0.15       168
#
# THRESHOLD: 0.9
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        52
#            1       0.00      0.00      0.00       116
#
#     accuracy                           0.31       168
#    macro avg       0.15      0.50      0.24       168
# weighted avg       0.10      0.31      0.15       168

# %% [markdown]
# ### Performances on Test

# %%
pred_somma = []
pred_tutti_verdi = []
pred_media = []
pred_mediana = []

for _, row in tqdm(test_df.iterrows()):
  colors_agreement, _ = tokens_evaluation.get_all_colors(row['tokens_list'], tokens_df_10)

  if 'NA' in colors_agreement:
    indexes = tokens_evaluation.find_NA_indices(colors_agreement)
    for new_word_index in range(len(indexes)) :
       colors_agreement[indexes[new_word_index]]=0

  colors_agreement = [i for i in colors_agreement if i != 0]

  if colors_agreement:

    pred_somma.append(sum(colors_agreement))
    pred_media.append(np.mean(colors_agreement))
    pred_mediana.append(np.median(colors_agreement))
    pred_tutti_verdi.append(min(colors_agreement))

  else:
    pred_somma.append(0)
    pred_media.append(0)
    pred_mediana.append(0)
    pred_tutti_verdi.append(0)
# Out:
# 168it [00:00, 590.29it/s]

# %%
print('SOMMA \n')
print(classification_report(test_df['disagreement'], [int(i>=0.9) for i in pred_somma] ))

print('\n MEDIA \n')
print(classification_report(test_df['disagreement'], [int(i>=0.4) for i in pred_media]))

print('\n MEDIANA \n')
print(classification_report(test_df['disagreement'], [int(i>=0.4) for i in pred_mediana]))

print('\n ALL GREEN \n')
print(classification_report(test_df['disagreement'], [int(i>=-0.3) for i in pred_tutti_verdi]))
# Out:
# stima NA: NO
# soglia coordinate: almeno 10 occorrenze
# valori non pesati
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.37      0.47        52
#            1       0.76      0.91      0.83       116
#
#     accuracy                           0.74       168
#    macro avg       0.71      0.64      0.65       168
# weighted avg       0.73      0.74      0.72       168
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.77      0.63        52
#            1       0.87      0.71      0.78       116
#
#     accuracy                           0.73       168
#    macro avg       0.71      0.74      0.71       168
# weighted avg       0.77      0.73      0.74       168
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.45      0.42      0.44        52
#            1       0.75      0.77      0.76       116
#
#     accuracy                           0.66       168
#    macro avg       0.60      0.60      0.60       168
# weighted avg       0.66      0.66      0.66       168
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.71      0.67        52
#            1       0.86      0.82      0.84       116
#
#     accuracy                           0.79       168
#    macro avg       0.75      0.77      0.76       168
# weighted avg       0.79      0.79      0.79       168

# %%
# open file in write mode
with open(r'./Results_NoEstimation/HS_Sum.txt', 'w') as fp:
    for item in pred_somma:
        # write each item on a new line
        fp.write("%s\n" % item)

with open(r'./Results_NoEstimation/HS_Mean.txt', 'w') as fp:
    for item in pred_media:
        # write each item on a new line
        fp.write("%s\n" % item)


with open(r'./Results_NoEstimation/HS_Median.txt', 'w') as fp:
    for item in pred_mediana:
        # write each item on a new line
        fp.write("%s\n" % item)

with open(r'./Results_NoEstimation/HS_Verdi.txt', 'w') as fp:
    for item in pred_tutti_verdi:
        # write each item on a new line
        fp.write("%s\n" % item)

# %% [markdown]
# # Mean contextualized
# mean of the contextualized vectors to obtain one vector per token

# %% [markdown]
# ## Context Embeddings for token in Train

# %%
sentences = list(train_df['original_text'])

# %%
from collections import OrderedDict

context_embeddings = []
context_tokens = []

for sentence in sentences:
  tokenized_text, list_token_embeddings = BERT_Embeddings.text_to_emb(sentence, tokenizer, model)

  # make ordered dictionary to keep track of the position of each word
  tokens = OrderedDict()

  # loop over tokens in sensitive sentence
  for token in tokenized_text[1:-1]:
    # keep track of position of word and whether it occurs multiple times
    if token in tokens:
      tokens[token] += 1
    else:
      tokens[token] = 1

    # compute the position of the current token
    token_indices = [i for i, t in enumerate(tokenized_text) if t == token]
    current_index = token_indices[tokens[token]-1]

    # get the corresponding embedding
    token_vec = list_token_embeddings[current_index]

    # save values
    context_tokens.append(token)
    context_embeddings.append(token_vec)

# %%
def find_token_indices(list_to_check, token):
    """
    Finds the indices of 'NA' values in a list.

    Args:
        list_to_check (list): List to check for 'NA' values.

    Returns:
        list: List of indices where 'NA' values are found.

    """
    indices = []
    for idx, value in enumerate(list_to_check):
        if value == token:
            indices.append(idx)
    return indices

# %%
def retrieve_elements(lst, indexes):
    return [lst[i] for i in indexes]

# %%
context_embeddings_mean = []
context_tokens_mean = []

for tk in set(context_tokens):
  indexes = find_token_indices(context_tokens, tk)
  context_tokens_mean.append(tk)
  context_embeddings_mean.append(torch.mean(torch.stack(retrieve_elements(context_embeddings, indexes)) , dim=0))#np.mean(list(retrieve_elements(context_embeddings, indexes))))

print(len(context_tokens_mean))
# Out:
# 2276

# %%
context_embeddings_mean_2 = []
context_tokens_mean_2 = []

for tk in set(context_tokens_mean):
  if tk in list(tokens_df_10['token']):
    indexes = find_token_indices(context_tokens_mean, tk)
    context_tokens_mean_2.append(tk)
    context_embeddings_mean_2.append(context_embeddings_mean[indexes[0]])

context_embeddings_mean = context_embeddings_mean_2
context_tokens_mean = context_tokens_mean_2

# %%
tokens_df = pd.read_csv('../Nuovi_Scores/brexit_scores.csv', sep='\t')
tokens_df_10 = tokens_df[tokens_df.occurrences >= 10]

# %% [markdown]
# ### G-Models

# %% [markdown]
# #### Threshold on DEV

# %%
pred_somma = []
pred_tutti_verdi = []
pred_media = []
pred_mediana = []
threshold=0.7

for _, row in tqdm(dev_df.iterrows()):
  colors_agreement, _ = tokens_evaluation.get_all_colors(row['tokens_list'], tokens_df_10)

  if 'NA' in colors_agreement:
    similar_words, distances_df, new_words  = BERT_Embeddings.find_similar_words(row['original_text'], tokens_evaluation.find_NA_indices(colors_agreement), tokenizer, context_tokens_mean,context_embeddings_mean, model, tokens_df_10)
    for i in range(0, len(new_words)):
      if list(distances_df.loc[(distances_df['new_token']==new_words[i])& (distances_df['distance']>=threshold)]['distance']):
        stimated_coordinate = np.average(
            list(distances_df.loc[(distances_df['new_token']==new_words[i]) & (distances_df['distance']>=threshold)]['Agreement_coordinate']),
            weights=list(distances_df.loc[(distances_df['new_token']==new_words[i])& (distances_df['distance']>=threshold)]['distance']))

        colors_agreement[tokens_evaluation.find_NA_indices(colors_agreement)[0]]=stimated_coordinate
      else: #if there isn't any word above the threshold
        colors_agreement[tokens_evaluation.find_NA_indices(colors_agreement)[0]]=0
  colors_agreement = [i for i in colors_agreement if i != 0]

  if colors_agreement:

    pred_somma.append(sum(colors_agreement))
    pred_media.append(np.mean(colors_agreement))
    pred_mediana.append(np.median(colors_agreement))
    pred_tutti_verdi.append(min(colors_agreement))

  else:
    pred_somma.append(0)
    pred_media.append(0)
    pred_mediana.append(0)
    pred_tutti_verdi.append(0)
# Out:
# 168it [00:38,  4.37it/s]

# %%
best_t = 0
best_f1 = 0
for t in np.arange(round(min(pred_somma)), round(max(pred_somma)), 0.1):
  t = round(t,1)
  report = classification_report(dev_df['disagreement'], [int(i>=t) for i in pred_somma], output_dict=True)
  if report['macro avg']['f1-score'] > best_f1:
    best_f1 = report['macro avg']['f1-score']
    best_t = t

print('SOMMA \n')
print('THRESHOLD: '+ str(best_t) + '\n')
print(classification_report(dev_df['disagreement'], [int(i>=best_t) for i in pred_somma] ))
# Out:
# SOMMA
#
# THRESHOLD: 1.9
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.42      0.50        52
#            1       0.77      0.88      0.82       116
#
#     accuracy                           0.74       168
#    macro avg       0.69      0.65      0.66       168
# weighted avg       0.72      0.74      0.72       168

# %%
best_t = 0
best_f1 = 0
pred = pred_media
for t in np.arange(round(min(pred)), round(max(pred)), 0.1):
  t = round(t,1)
  report = classification_report(dev_df['disagreement'], [int(i>=t) for i in pred], output_dict=True)
  if report['macro avg']['f1-score'] > best_f1:
    best_f1 = report['macro avg']['f1-score']
    best_t = t

print('MEDIA \n')
print('THRESHOLD: '+ str(best_t) + '\n')
print(classification_report(dev_df['disagreement'], [int(i>=best_t) for i in pred] ))
# Out:
# MEDIA
#
# THRESHOLD: 0.4
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.71      0.62        52
#            1       0.85      0.74      0.79       116
#
#     accuracy                           0.73       168
#    macro avg       0.70      0.73      0.71       168
# weighted avg       0.76      0.73      0.74       168

# %%
best_t = 0
best_f1 = 0
pred = pred_mediana
for t in np.arange(round(min(pred)), round(max(pred)), 0.1):
  t = round(t,1)
  report = classification_report(dev_df['disagreement'], [int(i>=t) for i in pred], output_dict=True)
  if report['macro avg']['f1-score'] > best_f1:
    best_f1 = report['macro avg']['f1-score']
    best_t = t

print('MEDIANA \n')
print('THRESHOLD: '+ str(best_t) + '\n')
print(classification_report(dev_df['disagreement'], [int(i>=best_t) for i in pred] ))
# Out:
# MEDIANA
#
# THRESHOLD: 0.4
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.42      0.47        52
#            1       0.76      0.84      0.80       116
#
#     accuracy                           0.71       168
#    macro avg       0.65      0.63      0.64       168
# weighted avg       0.69      0.71      0.70       168

# %%
best_t = 0
best_f1 = 0
pred = pred_tutti_verdi
for t in np.arange(round(min(pred)), round(max(pred)), 0.1):
  t = round(t,1)
  report = classification_report(dev_df['disagreement'], [int(i>=t) for i in pred], output_dict=True)
  if report['macro avg']['f1-score'] > best_f1:
    best_f1 = report['macro avg']['f1-score']
    best_t = t

print(' ALL GREEN \n')
print('THRESHOLD: '+ str(best_t) + '\n')
print(classification_report(dev_df['disagreement'], [int(i>=best_t) for i in pred] ))
# Out:
#  ALL GREEN
#
# THRESHOLD: -0.3
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.66        52
#            1       0.86      0.80      0.83       116
#
#     accuracy                           0.77       168
#    macro avg       0.74      0.76      0.75       168
# weighted avg       0.79      0.77      0.78       168

# %%
best_t = 0
best_f1 = 0
pred = pred_tutti_verdi
for t in np.arange(round(min(pred)), round(max(pred)), 0.1):
  t = round(t,1)
  report = classification_report(dev_df['disagreement'], [int(i>=t) for i in pred], output_dict=True)
  if report['macro avg']['f1-score'] >= best_f1:
    best_f1 = report['macro avg']['f1-score']
    best_t = t

print(' ALL GREEN \n')
print('THRESHOLD: '+ str(best_t) + '\n')
print(classification_report(dev_df['disagreement'], [int(i>=best_t) for i in pred] ))
# Out:
#  ALL GREEN
#
# THRESHOLD: -0.3
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.66        52
#            1       0.86      0.80      0.83       116
#
#     accuracy                           0.77       168
#    macro avg       0.74      0.76      0.75       168
# weighted avg       0.79      0.77      0.78       168

# %% [markdown]
# #### Performances on Test

# %%
pred_somma = []
pred_tutti_verdi = []
pred_media = []
pred_mediana = []
threshold=0.7

for _, row in tqdm(test_df.iterrows()):
  colors_agreement, _ = tokens_evaluation.get_all_colors(row['tokens_list'], tokens_df_10)

  if 'NA' in colors_agreement:
    similar_words, distances_df, new_words  = BERT_Embeddings.find_similar_words(row['original_text'], tokens_evaluation.find_NA_indices(colors_agreement), tokenizer, context_tokens_mean,context_embeddings_mean, model, tokens_df_10)
    for i in range(0, len(new_words)):
      if list(distances_df.loc[(distances_df['new_token']==new_words[i])& (distances_df['distance']>=threshold)]['distance']):
        stimated_coordinate = np.mean([a*b for a,b in zip(list(distances_df.loc[(distances_df['new_token']==new_words[i]) & (distances_df['distance']>=threshold)]['Agreement_coordinate']),
                             list(distances_df.loc[(distances_df['new_token']==new_words[i])& (distances_df['distance']>=threshold)]['distance']))])

        colors_agreement[tokens_evaluation.find_NA_indices(colors_agreement)[0]]=stimated_coordinate
      else: #if there isn't any word above the threshold
        colors_agreement[tokens_evaluation.find_NA_indices(colors_agreement)[0]]=0
  colors_agreement = [i for i in colors_agreement if i != 0]

  if colors_agreement:

    pred_somma.append(sum(colors_agreement))
    pred_media.append(np.mean(colors_agreement))
    pred_mediana.append(np.median(colors_agreement))
    pred_tutti_verdi.append(min(colors_agreement))

  else:
    pred_somma.append(0)
    pred_media.append(0)
    pred_mediana.append(0)
    pred_tutti_verdi.append(0)
# Out:
# 168it [00:41,  4.09it/s]

# %%
print('SOMMA \n')
print(classification_report(test_df['disagreement'], [int(i>=1.9) for i in pred_somma] ))

print('\n MEDIA \n')
print(classification_report(test_df['disagreement'], [int(i>=0.4) for i in pred_media]))

print('\n MEDIANA \n')
print(classification_report(test_df['disagreement'], [int(i>=0.4) for i in pred_mediana]))

print('\n ALL GREEN \n')
print(classification_report(test_df['disagreement'], [int(i>=-0.3) for i in pred_tutti_verdi]))
# Out:
# stima NA: NO
# soglia coordinate: almeno 10 occorrenze
# valori non pesati
# SOMMA
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.38      0.46        52
#            1       0.76      0.87      0.81       116
#
#     accuracy                           0.72       168
#    macro avg       0.67      0.63      0.64       168
# weighted avg       0.70      0.72      0.70       168
#
#
#  MEDIA
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.71      0.61        52
#            1       0.85      0.72      0.78       116
#
#     accuracy                           0.72       168
#    macro avg       0.69      0.72      0.70       168
# weighted avg       0.75      0.72      0.73       168
#
#
#  MEDIANA
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.42      0.41        52
#            1       0.73      0.72      0.72       116
#
#     accuracy                           0.62       168
#    macro avg       0.57      0.57      0.57       168
# weighted avg       0.63      0.62      0.63       168
#
#
#  ALL GREEN
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.75      0.69        52
#            1       0.88      0.81      0.84       116
#
#     accuracy                           0.79       168
#    macro avg       0.76      0.78      0.77       168
# weighted avg       0.80      0.79      0.80       168

# %%
# open file in write mode
with open(r'./Brexit_G-Sum.txt', 'w') as fp:
    for item in pred_somma:
        # write each item on a new line
        fp.write("%s\n" % item)

with open(r'./Brexit_G-Mean.txt', 'w') as fp:
    for item in pred_media:
        # write each item on a new line
        fp.write("%s\n" % item)

with open(r'./Brexit_G-Median.txt', 'w') as fp:
    for item in pred_mediana:
        # write each item on a new line
        fp.write("%s\n" % item)

with open(r'./Brexit_G-Min.txt', 'w') as fp:
    for item in pred_tutti_verdi:
        # write each item on a new line
        fp.write("%s\n" % item)
